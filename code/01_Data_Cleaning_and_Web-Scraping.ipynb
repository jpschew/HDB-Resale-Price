# %% [markdown]
# # Part 1. Data Cleaning and Web-scraping of location data

# %% [markdown]
# ## Import basic libraries and load data
#
# This section import the basic python libraries for usage as well as loading the data to check for any null values. Three datasets were loaded and ranges from 2012 to 2022. At the end of this section, the datasets were merged together as one.

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.86 µs

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
# data = pd.read_csv('./datasets/resale-flat-prices-based-on-approval-date-1990-1999.csv')
# data2 = pd.read_csv('./datasets/resale-flat-prices-based-on-approval-date-2000-feb-2012.csv')
data = pd.read_csv('./datasets/resale-flat-prices-based-on-registration-date-from-mar-2012-to-dec-2014.csv')
data2 = pd.read_csv('./datasets/resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv')
data3 = pd.read_csv('./datasets/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv')

# %%
data.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0
# 3            67.0  New Generation                 1984      320000.0
# 4            67.0  New Generation                 1980      321000.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52203 entries, 0 to 52202
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                52203 non-null  object
#  1   town                 52203 non-null  object
#  2   flat_type            52203 non-null  object
#  3   block                52203 non-null  object
#  4   street_name          52203 non-null  object
#  5   storey_range         52203 non-null  object
#  6   floor_area_sqm       52203 non-null  float64
#  7   flat_model           52203 non-null  object
#  8   lease_commence_date  52203 non-null  int64
#  9   resale_price         52203 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 4.0+ MB

# %%
data.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
data2.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37153 entries, 0 to 37152
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                37153 non-null  object
#  1   town                 37153 non-null  object
#  2   flat_type            37153 non-null  object
#  3   block                37153 non-null  object
#  4   street_name          37153 non-null  object
#  5   storey_range         37153 non-null  object
#  6   floor_area_sqm       37153 non-null  float64
#  7   flat_model           37153 non-null  object
#  8   lease_commence_date  37153 non-null  int64
#  9   remaining_lease      37153 non-null  int64
#  10  resale_price         37153 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 3.1+ MB

# %%
data2.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
data3.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120824 entries, 0 to 120823
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                120824 non-null  object
#  1   town                 120824 non-null  object
#  2   flat_type            120824 non-null  object
#  3   block                120824 non-null  object
#  4   street_name          120824 non-null  object
#  5   storey_range         120824 non-null  object
#  6   floor_area_sqm       120824 non-null  float64
#  7   flat_model           120824 non-null  object
#  8   lease_commence_date  120824 non-null  int64
#  9   remaining_lease      120824 non-null  object
#  10  resale_price         120824 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 10.1+ MB

# %%
data3.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
merge_data = pd.concat([data, data2, data3], axis=0, ignore_index=True)

# %%
merge_data.rename(columns={'month':'date'}, inplace=True)

# %%
merge_data.head()
# Out:
#       date        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0
# 3            67.0  New Generation                 1984      320000.0
# 4            67.0  New Generation                 1980      321000.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
merge_data.tail()
# Out:
#            date    town         flat_type block   street_name storey_range  \
# 210175  2022-02  YISHUN         EXECUTIVE   652  YISHUN AVE 4     04 TO 06
# 210176  2022-02  YISHUN         EXECUTIVE   324   YISHUN CTRL     04 TO 06
# 210177  2022-02  YISHUN         EXECUTIVE   824  YISHUN ST 81     10 TO 12
# 210178  2022-02  YISHUN  MULTI-GENERATION   633  YISHUN ST 61     04 TO 06
# 210179  2022-02  YISHUN  MULTI-GENERATION   632  YISHUN ST 61     10 TO 12
#
#         floor_area_sqm        flat_model  lease_commence_date  resale_price  \
# 210175           187.0         Apartment                 1992     1038000.0
# 210176           142.0         Apartment                 1988      680000.0
# 210177           146.0        Maisonette                 1987      800000.0
# 210178           171.0  Multi Generation                 1987      842000.0
# 210179           164.0  Multi Generation                 1987      845000.0
#
#            remaining_lease
# 210175  69 years 04 months
# ...

# %%
merge_data.isna().sum()
# Out:
# date                       0
# town                       0
# flat_type                  0
# block                      0
# street_name                0
# storey_range               0
# floor_area_sqm             0
# flat_model                 0
# lease_commence_date        0
# resale_price               0
# remaining_lease        52203
# dtype: int64

# %%
merge_data_drop = merge_data.drop(['remaining_lease'], axis=1)

# %%
merge_data_drop.isna().sum()
# Out:
# date                   0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
merge_data_drop['date']= pd.to_datetime(merge_data_drop['date'])

# %%
merge_data_drop['year'] = merge_data_drop['date'].dt.year
merge_data_drop['month'] = merge_data_drop['date'].dt.month

# %%
merge_data_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210180 entries, 0 to 210179
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 210180 non-null  datetime64[ns]
#  1   town                 210180 non-null  object
#  2   flat_type            210180 non-null  object
#  3   block                210180 non-null  object
#  4   street_name          210180 non-null  object
#  5   storey_range         210180 non-null  object
#  6   floor_area_sqm       210180 non-null  float64
#  7   flat_model           210180 non-null  object
#  8   lease_commence_date  210180 non-null  int64
#  9   resale_price         210180 non-null  float64
#  10  year                 210180 non-null  int64
#  11  month                210180 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 19.2+ MB

# %%
merge_data_drop.head()
# Out:
#         date        town flat_type block        street_name storey_range  \
# 0 2012-03-01  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1 2012-03-01  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2 2012-03-01  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3 2012-03-01  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4 2012-03-01  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  year  \
# 0            45.0        Improved                 1986      250000.0  2012
# 1            44.0        Improved                 1980      265000.0  2012
# 2            68.0  New Generation                 1980      315000.0  2012
# 3            67.0  New Generation                 1984      320000.0  2012
# 4            67.0  New Generation                 1980      321000.0  2012
#
#    month
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3

# %%
merge_data_drop['flat_type'].unique()
# Out:
# array(['2 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', 'EXECUTIVE',
#        'MULTI-GENERATION', '1 ROOM'], dtype=object)

# %% [markdown]
# ## Web-scraping of Location data using OneMap API
#
# This section scraps in the location data such as the longitude and latitude for the HDB flat using OneMap API. These data were added to the HDB dataset which will be needed to be used later to compute the distance to the nearest amenities like mrt stations, primary and secondary schools in the next part of the notebook.

# %%
import requests

# %%
test_data = merge_data_drop.loc[:,:]

# %%
test_data.head(10)
# Out:
#         date        town flat_type block        street_name storey_range  \
# 0 2012-03-01  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1 2012-03-01  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2 2012-03-01  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3 2012-03-01  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4 2012-03-01  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
# 5 2012-03-01  ANG MO KIO    3 ROOM   154   ANG MO KIO AVE 5     01 TO 05
# 6 2012-03-01  ANG MO KIO    3 ROOM   110   ANG MO KIO AVE 4     01 TO 05
# 7 2012-03-01  ANG MO KIO    3 ROOM   445  ANG MO KIO AVE 10     01 TO 05
# 8 2012-03-01  ANG MO KIO    3 ROOM   476  ANG MO KIO AVE 10     11 TO 15
# 9 2012-03-01  ANG MO KIO    3 ROOM   631   ANG MO KIO AVE 4     01 TO 05
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  year  \
# 0            45.0        Improved                 1986      250000.0  2012
# ...

# %%
test_data.tail(10)
# Out:
#              date    town         flat_type block   street_name storey_range  \
# 210170 2022-02-01  YISHUN            5 ROOM   647  YISHUN ST 61     04 TO 06
# 210171 2022-02-01  YISHUN            5 ROOM   730  YISHUN ST 71     01 TO 03
# 210172 2022-02-01  YISHUN            5 ROOM   841  YISHUN ST 81     07 TO 09
# 210173 2022-02-01  YISHUN         EXECUTIVE   664  YISHUN AVE 4     07 TO 09
# 210174 2022-02-01  YISHUN         EXECUTIVE   664  YISHUN AVE 4     10 TO 12
# 210175 2022-02-01  YISHUN         EXECUTIVE   652  YISHUN AVE 4     04 TO 06
# 210176 2022-02-01  YISHUN         EXECUTIVE   324   YISHUN CTRL     04 TO 06
# 210177 2022-02-01  YISHUN         EXECUTIVE   824  YISHUN ST 81     10 TO 12
# 210178 2022-02-01  YISHUN  MULTI-GENERATION   633  YISHUN ST 61     04 TO 06
# 210179 2022-02-01  YISHUN  MULTI-GENERATION   632  YISHUN ST 61     10 TO 12
#
#         floor_area_sqm        flat_model  lease_commence_date  resale_price  \
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210180 entries, 0 to 210179
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 210180 non-null  datetime64[ns]
#  1   town                 210180 non-null  object
#  2   flat_type            210180 non-null  object
#  3   block                210180 non-null  object
#  4   street_name          210180 non-null  object
#  5   storey_range         210180 non-null  object
#  6   floor_area_sqm       210180 non-null  float64
#  7   flat_model           210180 non-null  object
#  8   lease_commence_date  210180 non-null  int64
#  9   resale_price         210180 non-null  float64
#  10  year                 210180 non-null  int64
#  11  month                210180 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(6)
# memory usage: 19.2+ MB

# %%
import datetime
def scrap_hdb_data(df):
    cont_scrap = True
    a = datetime.datetime.now()
    
    if 'longitude' not in df:
        df['longitude'] = ''
    if 'latitude' not in df:
        df['latitude'] = ''

#     while cont_scrap:
    for index, row in df.iterrows():
        query = row['street_name'] + ' ' + row['block']
    #     print(query)
        url = f'https://developers.onemap.sg/commonapi/search?searchVal={query}&returnGeom=Y&getAddrDetails=Y'
    #     print(url)
        res = requests.get(url)
        if res.status_code != 200:
            print('error code')
            break
    #     print(res)
        data = res.json()
#         print(data['results'][0])
    #     break
        try:
            df['longitude'][index] = data['results'][0]['LONGITUDE']
            df['latitude'][index] = data['results'][0]['LATITUDE']
        except:
            pass
        
        if (index+1) % 1000 == 0:
            b = datetime.datetime.now()
            print(f'{(index+1)} hdb data have been added longitude and latitude values for {b-a} seconds.')
    c = datetime.datetime.now()
    print(f'Total time taken to scrap {len(df)} hdb data is {c-a} seconds.')
    return df

# %%
len(test_data)
# Out:
# 210180

# %%
test_data = scrap_hdb_data(test_data)
# Out:
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'][index] = data['results'][0]['LONGITUDE']
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'][index] = data['results'][0]['LATITUDE']
# 1000 hdb data have been added longitude and latitude values for 0:02:18.977059 seconds.
# 2000 hdb data have been added longitude and latitude values for 0:04:41.764520 seconds.
# ...

# %%
test_data.to_csv('./datasets/merge_data_lon_lat.csv', index=False)

# %%
test_data[82192:82200]
# Out:
#             date             town flat_type block       street_name  \
# 82192 2016-08-01  KALLANG/WHAMPOA    4 ROOM   108         MCNAIR RD
# 82193 2016-08-01  KALLANG/WHAMPOA    4 ROOM   681    RACE COURSE RD
# 82194 2016-08-01  KALLANG/WHAMPOA    4 ROOM    13  UPP BOON KENG RD
# 82195 2016-08-01  KALLANG/WHAMPOA    4 ROOM   684    RACE COURSE RD
# 82196 2016-08-01  KALLANG/WHAMPOA    4 ROOM   103         TOWNER RD
# 82197 2016-08-01  KALLANG/WHAMPOA    4 ROOM    13      FARRER PK RD
# 82198 2016-08-01  KALLANG/WHAMPOA    4 ROOM    2D  UPP BOON KENG RD
# 82199 2016-08-01  KALLANG/WHAMPOA    4 ROOM    5A  UPP BOON KENG RD
#
#       storey_range  floor_area_sqm flat_model  lease_commence_date  \
# 82192     04 TO 06           104.0    Model A                 1987
# 82193     04 TO 06           103.0    Model A                 1986
# 82194     07 TO 09           101.0    Model A                 1999
# 82195     10 TO 12           103.0    Model A                 1986
# ...

# %%
test_data[82193:] = scrap_hdb_data(test_data[82193:])
# Out:
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'][index] = data['results'][0]['LONGITUDE']
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'][index] = data['results'][0]['LATITUDE']
# 83000 hdb data have been added longitude and latitude values for 0:01:57.485017 seconds.
# 84000 hdb data have been added longitude and latitude values for 0:04:10.554344 seconds.
# ...

# %%
test_data[126877:126880]
# Out:
#              date     town flat_type block     street_name storey_range  \
# 126877 2018-10-01  HOUGANG    5 ROOM   167   HOUGANG AVE 1     10 TO 12
# 126878 2018-10-01  HOUGANG    5 ROOM   831    HOUGANG CTRL     01 TO 03
# 126879 2018-10-01  HOUGANG    5 ROOM   409  HOUGANG AVE 10     10 TO 12
#
#         floor_area_sqm flat_model  lease_commence_date  resale_price  year  \
# 126877           123.0   Improved                 1997      540000.0  2018
# 126878           122.0   Improved                 1992      550000.0  2018
# 126879           121.0   Improved                 1985      580000.0  2018
#
#         month         longitude          latitude
# 126877     10  103.888448131093  1.35181593598792
# 126878     10
# 126879     10

# %%
test_data[126878:] = scrap_hdb_data(test_data[126878:])
# Out:
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'][index] = data['results'][0]['LONGITUDE']
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/1431647851.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'][index] = data['results'][0]['LATITUDE']
# 127000 hdb data have been added longitude and latitude values for 0:00:21.032215 seconds.
# 128000 hdb data have been added longitude and latitude values for 0:02:48.211276 seconds.
# ...

# %%
test_data.head()
# Out:
#         date        town flat_type block        street_name storey_range  \
# 0 2012-03-01  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1 2012-03-01  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2 2012-03-01  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3 2012-03-01  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4 2012-03-01  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  year  \
# 0            45.0        Improved                 1986      250000.0  2012
# 1            44.0        Improved                 1980      265000.0  2012
# 2            68.0  New Generation                 1980      315000.0  2012
# 3            67.0  New Generation                 1984      320000.0  2012
# 4            67.0  New Generation                 1980      321000.0  2012
#
#    month         longitude          latitude
# ...

# %%
test_data.tail()
# Out:
#              date    town         flat_type block   street_name storey_range  \
# 210175 2022-02-01  YISHUN         EXECUTIVE   652  YISHUN AVE 4     04 TO 06
# 210176 2022-02-01  YISHUN         EXECUTIVE   324   YISHUN CTRL     04 TO 06
# 210177 2022-02-01  YISHUN         EXECUTIVE   824  YISHUN ST 81     10 TO 12
# 210178 2022-02-01  YISHUN  MULTI-GENERATION   633  YISHUN ST 61     04 TO 06
# 210179 2022-02-01  YISHUN  MULTI-GENERATION   632  YISHUN ST 61     10 TO 12
#
#         floor_area_sqm        flat_model  lease_commence_date  resale_price  \
# 210175           187.0         Apartment                 1992     1038000.0
# 210176           142.0         Apartment                 1988      680000.0
# 210177           146.0        Maisonette                 1987      800000.0
# 210178           171.0  Multi Generation                 1987      842000.0
# 210179           164.0  Multi Generation                 1987      845000.0
#
# ...

# %%
test_data.to_csv('./datasets/merge_data_lon_lat_final.csv', index=False)

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210180 entries, 0 to 210179
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 210180 non-null  datetime64[ns]
#  1   town                 210180 non-null  object
#  2   flat_type            210180 non-null  object
#  3   block                210180 non-null  object
#  4   street_name          210180 non-null  object
#  5   storey_range         210180 non-null  object
#  6   floor_area_sqm       210180 non-null  float64
#  7   flat_model           210180 non-null  object
#  8   lease_commence_date  210180 non-null  int64
#  9   resale_price         210180 non-null  float64
#  10  year                 210180 non-null  int64
#  11  month                210180 non-null  int64
#  12  longitude            210180 non-null  object
#  13  latitude             210180 non-null  object
# ...

# %% [markdown]
# ## Web-scraping of amenities like MRT stations, Primary and Secondary Schools
# This section scraps in the location data of all the MRT stations, primary and secondary schools in Singapore and saved to their respective dataframes. These data were needed to add the respective amenities that were nearest to all the HDB flats in the dataset. Some data cleaning were done in this section to remove duplicate mrt stations and schools.

# %%
# var_list in the sequnce of names, long and lat
# amenity is the string to be queried
def scrap_amenity_data(amenity, var_list):
    # get mrt
    to_scrap = True
    page_num = 1
    var_list[0] = []
    var_list[1] = []
    var_list[2] = []
    while to_scrap:
        query = amenity
    #     print(query)
        url = f'https://developers.onemap.sg/commonapi/search?searchVal={query}&returnGeom=Y&getAddrDetails=Y&pageNum={page_num}'
    #     print(url)
        res = requests.get(url)
        if res.status_code != 200:
            break
    #     print(res)
        data = res.json()
        print(f'{page_num} page(s) retrieved')
    #     print(data['results'])
    #     for page in range(page_num, data['totalNumPages']+1):
    #     break
        for info in data['results']:
            var_list[0].append(info['BUILDING'])
            var_list[1].append(info['LONGITUDE'])
            var_list[2].append(info['LATITUDE'])
    #             print(mrt_names, mrt_long, mrt_lat)
    #             break
        page_num += 1
        if page_num > data['totalNumPages']:
            to_scrap = False
    # each page 10 mrt, total 91 pages, <=910 mrt
    print(f'The total number of {amenity} retrieved is {len(var_list[0])}') 
    return var_list

# %%
def list_to_rm(df, var_list, amenity):
    for string in var_list:
        df[amenity] = df[amenity].str.replace(string, '')

# %%
def check_amenity(df, amenity):
    amenity_dict = {'mrt': 'mrt stations', 'pri_sch': 'primary schools', 'sec_sch': 'secondary schools'}
    amenity_sorted = df[amenity].tolist()
    amenity_sorted.sort()
    print(amenity_sorted)
    print(f'The number of {amenity_dict[amenity]} is {len(df[amenity])}.')

# %%
# %time
# # series.str.replace() uses regular expression
# # . means any char except new line
# # means 0 or more instances of pattern from the left
# string_to_rm = ['NTUC', 'OCBC', 'UOB', 'DBS', 'MRT CIRCLE LINE STATION', 'NEL', 'MRT STATION.*']
# for string in string_to_rm:
#     mrt_df['mrt'] = mrt_df['mrt'].str.replace(string, '')

mrt = scrap_amenity_data('mrt station', ['mrt', 'mrt_long', 'mrt_lat'])
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 8.82 µs
# 1 page(s) retrieved
# 2 page(s) retrieved
# 3 page(s) retrieved
# 4 page(s) retrieved
# 5 page(s) retrieved
# 6 page(s) retrieved
# 7 page(s) retrieved
# 8 page(s) retrieved
# 9 page(s) retrieved
# 10 page(s) retrieved
# 11 page(s) retrieved
# 12 page(s) retrieved
# 13 page(s) retrieved
# 14 page(s) retrieved
# 15 page(s) retrieved
# 16 page(s) retrieved
# 17 page(s) retrieved
# 18 page(s) retrieved
# 19 page(s) retrieved
# 20 page(s) retrieved
# 21 page(s) retrieved
# 22 page(s) retrieved
# 23 page(s) retrieved
# 24 page(s) retrieved
# 25 page(s) retrieved
# 26 page(s) retrieved
# 27 page(s) retrieved
# 28 page(s) retrieved
# 29 page(s) retrieved
# 30 page(s) retrieved
# 31 page(s) retrieved
# 32 page(s) retrieved
# 33 page(s) retrieved
# 34 page(s) retrieved
# 35 page(s) retrieved
# 36 page(s) retrieved
# 37 page(s) retrieved
# 38 page(s) retrieved
# 39 page(s) retrieved
# 40 page(s) retrieved
# ...

# %%
mrt_df = pd.DataFrame(columns=['mrt', 'mrt_long', 'mrt_lat'])
mrt_df
# Out:
# Empty DataFrame
# Columns: [mrt, mrt_long, mrt_lat]
# Index: []

# %%
mrt_df['mrt'] = mrt[0]
mrt_df['mrt_long'] = mrt[1]
mrt_df['mrt_lat'] = mrt[2]

# %%
mrt_list = ['NTUC', 'OCBC', 'UOB', 'DBS', 'MRT CIRCLE LINE STATION', 'NEL', 'MRT STATION.*']
# mrt_list2 = ['/ESPLANADE', 'CITYHALL', 'CLARK QUAY', 'HABOURFRONT', 'HOLLAND VILAGE', 'HOUGANG  BRANCH', \
#              'ONE - NORTH', ' ROAD', 'ROCHER', 'WOODLANDS  EBC', 'YEE TEE', 'ONENORTH']
list_to_rm(mrt_df, mrt_list, 'mrt')
# list_to_rm(mrt_df, mrt_list2, 'mrt')
# Out:
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/4173840903.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[amenity] = df[amenity].str.replace(string, '')

# %%
mrt_df['mrt'] = mrt_df['mrt'].str.replace('MRT', '')
mrt_df['mrt'] = mrt_df['mrt'].str.lstrip()
mrt_df['mrt'] = mrt_df['mrt'].str.rstrip()
# mrt_df.drop_duplicates(subset=['mrt'], ignore_index=True, inplace=True)

# %%
mrt_list2 = ['/ESPLANADE', 'CITYHALL', 'CLARK QUAY', 'HABOURFRONT', 'HOLLAND VILAGE', 'HOUGANG  BRANCH', \
             'ONE - NORTH', ' ROAD', 'ROCHER', 'WOODLANDS  EBC', 'YEE TEE', 'ONE-NORTH']
list_to_rm(mrt_df, mrt_list2, 'mrt')

# %%
mrt_df.drop_duplicates(subset=['mrt'], ignore_index=True, inplace=True)

# %%
# remove mrt with station
mrt_df = mrt_df[mrt_df['mrt'] != '']

# %%
mrt_df
# Out:
#                     mrt          mrt_long           mrt_lat
# 0         UPPER THOMSON  103.832898468504  1.35441643365401
# 1             CALDECOTT  103.840161782075  1.33724561271722
# 2                CASHEW   103.76443921414  1.36981544925552
# 3                LENTOR  103.835743809669  1.38550657972169
# 4              SOMERSET  103.839085753124  1.30026416739006
# 5            MARINA BAY  103.854595522263    1.276410298755
# 6           SHENTON WAY  103.850367596067   1.2777168283425
# 7     MARINA SOUTH PIER  103.862447515736  1.27102703612006
# 8              BAYFRONT  103.859079764874  1.28187378879209
# 9              DOWNTOWN  103.852840829581  1.27944638178916
# 10   GARDENS BY THE BAY  103.867454664421  1.27848725876303
# 11         MARINA SOUTH  103.863574321728  1.27455475919137
# 12               NAPIER  103.818967003926  1.30678307789908
# 13     KING ALBERT PARK  103.783399113441  1.33566161262214
# 14                 EXPO  103.962374747451  1.33538252614956
# ...

# %%
check_amenity(mrt_df, 'mrt')
# Out:
# ['ADMIRALTY', 'ALJUNIED', 'ANG MO KIO', 'BARTLEY', 'BAYFRONT', 'BAYSHORE', 'BEAUTY WORLD', 'BEDOK', 'BEDOK NORTH', 'BEDOK RESERVOIR', 'BEDOK SOUTH', 'BENCOOLEN', 'BENDEMEER', 'BISHAN', 'BOON KENG', 'BOON LAY', 'BOTANIC GARDENS', 'BRADDELL', 'BRAS BASAH', 'BRIGHT HILL', 'BUANGKOK', 'BUGIS', 'BUKIT BATOK', 'BUKIT BROWN', 'BUKIT GOMBAK', 'BUKIT PANJANG', 'BUONA VISTA', 'CALDECOTT', 'CANBERRA', 'CANTONMENT', 'CASHEW', 'CHANGI AIRPORT', 'CHINATOWN', 'CHINESE GARDEN', 'CHOA CHU KANG', 'CITY HALL', 'CLARKE QUAY', 'CLEMENTI', 'COMMONWEALTH', 'DAKOTA', 'DHOBY GHAUT', 'DOVER', 'DOWNTOWN', 'ESPLANADE', 'EUNOS', 'EXPO', 'FARRER', 'FARRER PARK', 'FORT CANNING', 'GARDENS BY THE BAY', 'GEYLANG BAHRU', 'GREAT WORLD', 'GUL CIRCLE', 'HARBOURFRONT', 'HAVELOCK', 'HAW PAR VILLA', 'HILLVIEW', 'HOLLAND VILLAGE', 'HOUGANG', 'JALAN BESAR', 'JOO KOON', 'JURONG EAST', 'KAKI BUKIT', 'KALLANG', 'KATONG PARK', 'KEMBANGAN', 'KENT RIDGE', 'KEPPEL', 'KHATIB', 'KING ALBERT PARK', 'KOVAN', 'KRANJI', 'LABRADOR PARK', '
# ...

# %%
mrt_df.to_csv('./datasets/mrt_data.csv', index=False)

# %%
# %time
pri_sch = scrap_amenity_data('primary school', ['pri_sch', 'pri_sch_long', 'pri_sch_lat'])
# Out:
# CPU times: user 4 µs, sys: 8 µs, total: 12 µs
# Wall time: 17.2 µs
# 1 page(s) retrieved
# 2 page(s) retrieved
# 3 page(s) retrieved
# 4 page(s) retrieved
# 5 page(s) retrieved
# 6 page(s) retrieved
# 7 page(s) retrieved
# 8 page(s) retrieved
# 9 page(s) retrieved
# 10 page(s) retrieved
# 11 page(s) retrieved
# 12 page(s) retrieved
# 13 page(s) retrieved
# 14 page(s) retrieved
# 15 page(s) retrieved
# 16 page(s) retrieved
# 17 page(s) retrieved
# 18 page(s) retrieved
# 19 page(s) retrieved
# 20 page(s) retrieved
# 21 page(s) retrieved
# 22 page(s) retrieved
# The total number of primary school retrieved is 215

# %%
pri_sch_df = pd.DataFrame(columns=['pri_sch', 'pri_sch_long', 'pri_sch_lat'])
pri_sch_df
# Out:
# Empty DataFrame
# Columns: [pri_sch, pri_sch_long, pri_sch_lat]
# Index: []

# %%
pri_sch_df['pri_sch'] = pri_sch[0]
pri_sch_df['pri_sch_long'] = pri_sch[1]
pri_sch_df['pri_sch_lat'] = pri_sch[2]

# %%
pri_sch_df
# Out:
#                                                pri_sch      pri_sch_long  \
# 0                              ZHONGHUA PRIMARY SCHOOL  103.869762438084
# 1                              ZHENGHUA PRIMARY SCHOOL  103.769313521752
# 2                               ZHANGDE PRIMARY SCHOOL  103.825951875662
# 3                                 YUMIN PRIMARY SCHOOL  103.950461927088
# 4                                 YUHUA PRIMARY SCHOOL  103.741105772644
# 5                               YU NENG PRIMARY SCHOOL  103.932144857355
# 6                                JIEMIN PRIMARY SCHOOL  103.830425490093
# 7                                XISHAN PRIMARY SCHOOL  103.837755319448
# 8                         AHMAD IBRAHIM PRIMARY SCHOOL  103.832942401086
# 9                                YISHUN PRIMARY SCHOOL  103.834087115915
# 10                              PEIYING PRIMARY SCHOOL  103.830417090698
# 11                           NORTH VIEW PRIMARY SCHOOL  103.848190787869
# ...

# %%
pri_sch_list = ['AFTERSCHOOL @ ', 'AMP-MERCU STUDENT CARE CENTRE @ ', 'BIG HEART STUDENT CARE ', \
                'COMMIT LEARNING SCHOOLHOUSE @ ', 'KNOWLEDGE PARK EDUCARE PTE LTD ', 'LEARNING LEAP PTE LTD ', \
                'LEARNING STUDIO EDUCARE @ ', 'POWERLIFE STUDENT SERVICES @ ', 'SHG STUDENT CARE ', \
                'THE LEARNING HARBOUR @ ', 'TRI-LOVE STUDENT CARE @ ', 'WHEE!CANOPUS STUDENT CARE @ ', \
                'WHEE!CANOPUS STUDENT CARE @ ', 'YMCA STUDENT CARE CENTRE @ ', '(', ')', \
                ' JAN 2019 - DEC 2021', ' U/C', '[', ']']
list_to_rm(pri_sch_df, pri_sch_list, 'pri_sch')
# Out:
# /var/folders/_7/n757v49173n9brml80vmygx80000gn/T/ipykernel_53468/4173840903.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df[amenity] = df[amenity].str.replace(string, '')

# %%
pri_sch_df.drop_duplicates(subset=['pri_sch'], ignore_index=True, inplace=True)

# %%
check_amenity(pri_sch_df, 'pri_sch')
# Out:
# ['ADMIRALTY PRIMARY SCHOOL', 'AHMAD IBRAHIM PRIMARY SCHOOL', 'ALEXANDRA PRIMARY SCHOOL', 'ANCHOR GREEN PRIMARY SCHOOL', 'ANDERSON PRIMARY SCHOOL', 'ANG MO KIO PRIMARY SCHOOL', 'ANGLO-CHINESE SCHOOL PRIMARY', 'ANGSANA PRIMARY SCHOOL', 'AVONDALE GRAMMAR SCHOOL PRIMARY & MIDDLE YEARS CAMPUS', 'BEACON PRIMARY SCHOOL', 'BEDOK GREEN PRIMARY SCHOOL', 'BENDEMEER PRIMARY SCHOOL', 'BLANGAH RISE PRIMARY SCHOOL', 'BOON LAY GARDEN PRIMARY SCHOOL', 'BUKIT PANJANG PRIMARY SCHOOL', 'BUKIT TIMAH PRIMARY SCHOOL', 'BUKIT VIEW PRIMARY SCHOOL', 'CANBERRA PRIMARY SCHOOL', 'CANOSSA CATHOLIC PRIMARY SCHOOL', 'CANTONMENT PRIMARY SCHOOL', 'CASUARINA PRIMARY SCHOOL', 'CATHOLIC HIGH SCHOOL PRIMARY', 'CEDAR PRIMARY SCHOOL', 'CHANGKAT PRIMARY SCHOOL', 'CHONGZHENG PRIMARY SCHOOL', 'CHUA CHU KANG PRIMARY SCHOOL', 'CLEMENTI PRIMARY SCHOOL', 'COMPASSVALE PRIMARY SCHOOL', 'CONCORD PRIMARY SCHOOL', 'CORPORATION PRIMARY SCHOOL', 'DAMAI PRIMARY SCHOOL', 'DAZHONG PRIMARY SCHOOL', 'EAST SPRING PRIMARY SCHOOL', 'EDGEFIELD P
# ...

# %%
pri_sch_df.to_csv('./datasets/pri_sch_data.csv', index=False)

# %%
# %time
sec_sch = scrap_amenity_data('secondary school', ['sec_sch', 'sec_sch_long', 'sec_sch_lat'])
# Out:
# CPU times: user 4 µs, sys: 3 µs, total: 7 µs
# Wall time: 12.9 µs
# 1 page(s) retrieved
# 2 page(s) retrieved
# 3 page(s) retrieved
# 4 page(s) retrieved
# 5 page(s) retrieved
# 6 page(s) retrieved
# 7 page(s) retrieved
# 8 page(s) retrieved
# 9 page(s) retrieved
# 10 page(s) retrieved
# 11 page(s) retrieved
# 12 page(s) retrieved
# The total number of secondary school retrieved is 116

# %%
sec_sch_df = pd.DataFrame(columns=['sec_sch', 'sec_sch_long', 'sec_sch_lat'])
sec_sch_df
# Out:
# Empty DataFrame
# Columns: [sec_sch, sec_sch_long, sec_sch_lat]
# Index: []

# %%
sec_sch_df['sec_sch'] = sec_sch[0]
sec_sch_df['sec_sch_long'] = sec_sch[1]
sec_sch_df['sec_sch_lat'] = sec_sch[2]

# %%
sec_sch_df.drop_duplicates(subset=['sec_sch'], ignore_index=True, inplace=True)

# %%
check_amenity(sec_sch_df, 'sec_sch')
# Out:
# ['ADMIRALTY SECONDARY SCHOOL', 'AHMAD IBRAHIM SECONDARY SCHOOL', 'ANDERSON SECONDARY SCHOOL', 'ANG MO KIO SECONDARY SCHOOL', 'BARTLEY SECONDARY SCHOOL', 'BEATTY SECONDARY SCHOOL', 'BEDOK GREEN SECONDARY SCHOOL', 'BEDOK SOUTH SECONDARY SCHOOL', 'BEDOK VIEW SECONDARY SCHOOL', 'BENDEMEER SECONDARY SCHOOL', 'BOON LAY SECONDARY SCHOOL', 'BOWEN SECONDARY SCHOOL', 'BROADRICK SECONDARY SCHOOL', 'BUKIT BATOK SECONDARY SCHOOL', 'BUKIT MERAH SECONDARY SCHOOL', 'BUKIT VIEW SECONDARY SCHOOL', 'CANBERRA SECONDARY SCHOOL', "CEDAR GIRLS' SECONDARY SCHOOL", 'CHANGKAT CHANGI SECONDARY SCHOOL', 'CHRIST CHURCH SECONDARY SCHOOL', 'CHUA CHU KANG SECONDARY SCHOOL', 'CLEMENTI TOWN SECONDARY SCHOOL', 'COMMONWEALTH SECONDARY SCHOOL', 'COMPASSVALE SECONDARY SCHOOL', 'CREST SECONDARY SCHOOL', 'DAMAI SECONDARY SCHOOL', 'DEYI SECONDARY SCHOOL', 'DUNEARN SECONDARY SCHOOL', 'DUNMAN SECONDARY SCHOOL', 'EAST SPRING SECONDARY SCHOOL', 'EDGEFIELD SECONDARY SCHOOL', 'EVERGREEN SECONDARY SCHOOL', 'FAIRFIELD METHODIST SCH
# ...

# %%
sec_sch_df.to_csv('./datasets/sec_sch_data.csv', index=False)
